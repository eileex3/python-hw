# %% [markdown]
# <a href="https://colab.research.google.com/github/eileex3/python-hw/blob/main/Copy_of_Python_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy

# %% [markdown]
# Importing panda for data loading and exploration.
# Matplotlib, Seaborn for Visualization

# %%
df = pd.read_json("https://healthdata.gov/resource/a6za-z3xi.json")

# %%
df
# Out:
#    state  ...  :@computed_region_pqdx_y6mm
# 0     AZ  ...                          3.0
# 1     AR  ...                          4.0
# 2     CA  ...                          5.0
# 3     GA  ...                          NaN
# 4     LA  ...                         19.0
# ..   ...  ...                          ...
# 59    OK  ...                         37.0
# 60    CA  ...                          5.0
# 61    AR  ...                          4.0
# 62    NC  ...                         34.0
# 63    VT  ...                         46.0
#
# [64 rows x 99 columns]

# %% [markdown]
# Each row represent facilities currently in suspense in most states in the United States regarding CoP requirements due to being in a work plan or other related reasons. Organized by state, ccn, facility name and street address.

# %%
df.describe()
# Out:
#                  ccn  ...  :@computed_region_pqdx_y6mm
# count      64.000000  ...                    54.000000
# mean   300451.140625  ...                    26.629630
# std    195192.233582  ...                    17.543796
# min     31300.000000  ...                     3.000000
# 25%     54137.750000  ...                     5.000000
# 50%    351339.000000  ...                    34.000000
# 75%    470014.250000  ...                    44.000000
# max    670314.000000  ...                    50.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# #statistic summary for certified bed count
# mean average of bed count is 80 beds for the certified bed count associated with the hospital in the CMS POS file which means data on characteristics of hospitals and other types of healthcare facilities.
